# %%
# !pip install gensim spacy
# !pip install tk
# !python -m spacy download en_core_web_sm
# Out:
# ...
#    ---------------------------------------- 0.0/24.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/24.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/24.0 MB 217.9 kB/s eta 0:01:51
#    ---------------------------------------- 0.1/24.0 MB 657.6 kB/s eta 0:00:37
#     --------------------------------------- 0.6/24.0 MB 3.5 MB/s eta 0:00:07
#    - -------------------------------------- 1.0/24.0 MB 5.0 MB/s eta 0:00:05
#    -- ------------------------------------- 1.4/24.0 MB 5.4 MB/s eta 0:00:05
#    -- ------------------------------------- 1.7/24.0 MB 5.4 MB/s eta 0:00:05
#    --- ------------------------------------ 1.9/24.0 MB 5.2 MB/s eta 0:00:05
#    --- ------------------------------------ 2.1/24.0 MB 5.2 MB/s eta 0:00:05
#    --- ------------------------------------ 2.4/24.0 MB 5.3 MB/s eta 0:00:05
#    ---- ----------------------------------- 2.7/24.0 MB 5.3 MB/s eta 0:00:05
# ...

# %%
# Read the medical records from a file
with open('medical_records.txt', 'r') as file:
    medical_records = file.readlines()

# Preprocess the data (remove sensitive information and standardize formatting)
def preprocess_record(record):
    #Implement your data preprocessing logic here
    return record
preprocessed_records = [preprocess_record(record) for record in medical_records]
